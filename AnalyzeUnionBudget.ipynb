# %%
import pandas as pd
import numpy as np
dataPath = "/media/cds/storage/DATA-1/hari/ResearchMethods/Module4_ResearchMethods/Data"

# %%
import os
files = sorted(os.listdir(dataPath))
for file in files:
    print(file, len(pd.read_csv(os.path.join(dataPath, file))))
    display(pd.read_csv(os.path.join(dataPath, file)))
# Out:
# Allocation_for_Welfare_of_Children-2021-2022.csv 144
#           Category      Sl. No.  \
# 0      DemandNo. 3            1
# 1      DemandNo. 3            2
# 2      DemandNo. 3            3
# 3      DemandNo. 3          NaN
# 4      DemandNo. 4            1
# ..             ...          ...
# 139  DemandNo. 100            9
# 140  DemandNo. 100           10
# 141  DemandNo. 100          NaN
# 142  DemandNo. 101            1
# 143    Grand Total  Grand Total
#
#                                    Ministry/Department  \
# 0                                        Atomic Energy
# 1                                        Atomic Energy
# 2                                        Atomic Energy
# 3                                        Atomic Energy
# 4    Ministry of Ayurveda, Yoga and Naturopathy, Un...
# ..                                                 ...
# 139           Ministry of Women and Child Development
# 140           Ministry of Women and Child Development
# ...
